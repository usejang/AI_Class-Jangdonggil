# %%
# 기존의 이미지 데이터가 적을 때 사용 : 이미지의 갯수를 확장
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import  optimizers

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# 이미지 확장
train_datagen = ImageDataGenerator(rescale=1./255,
                                  horizontal_flip=True,
                                  width_shift_range=0.1,
                                  height_shift_range=0.1,
#                                   rotation_range=5,
#                                   shear_range=0.7,
#                                   zoom_range=[0.9, 2.2],
#                                   vertical_flip=True,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
    './colab_train_test/train',  # 학습셋이 있는 폴더
    target_size=(150,150),
    batch_size=5,
    class_mode='binary')

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    './colab_train_test/test',  # 학습셋이 있는 폴더
    target_size=(150,150),
    batch_size=5,
    class_mode='binary')
# Out:
# Found 160 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.

# %%
# CNN 모델 만들기
model = Sequential()
model.add(Conv2D(32, (3,3), input_shape=(150,150,3), activation='relu'))
model.add(MaxPooling2D(2))
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(2))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

# %%
# 모델 컴파일 
model.compile(loss='sparse_categorical_crossentropy', 
              optimizer=optimizers.Adam(learning_rate=0.0002),
             metrics='accuracy')

# 모델 실행
# history = model.fit_generator( 
history = model.fit(     
    train_generator,
    steps_per_epoch=32,
    epochs=30,
    validation_data=test_generator,
    validation_steps=4)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 2s 50ms/step - loss: 0.7371 - accuracy: 0.4563 - val_loss: 0.6880 - val_accuracy: 0.5000
# Epoch 2/30
# 32/32 [==============================] - 2s 48ms/step - loss: 0.6960 - accuracy: 0.5188 - val_loss: 0.6998 - val_accuracy: 0.4000
# Epoch 3/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.6867 - accuracy: 0.5250 - val_loss: 0.6625 - val_accuracy: 0.6000
# Epoch 4/30
# 32/32 [==============================] - 1s 45ms/step - loss: 0.6797 - accuracy: 0.5562 - val_loss: 0.6365 - val_accuracy: 0.6500
# Epoch 5/30
# 32/32 [==============================] - 1s 46ms/step - loss: 0.6690 - accuracy: 0.6062 - val_loss: 0.6700 - val_accuracy: 0.5000
# Epoch 6/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.6729 - accuracy: 0.6125 - val_loss: 0.6488 - val_accuracy: 0.6500
# Epoch 7/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.6266 - accuracy: 0.7312 - val_loss: 0.5651 - val_accuracy: 0.8000
# Epoch 8/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.6195 - accuracy: 0.6687 - val_loss: 0.5927 - val_accuracy: 0.8000
# Epoch 9/30
# 32/32 [==============================] - 2s 46ms/step - loss: 0.6091 - accuracy: 0.6875 - val_loss: 0.5943 - val_accuracy: 0.6000
# Epoch 10/30
# 32/32 [==============================] - 2s 46ms/step - loss: 0.5881 - accuracy: 0.7125 - val_loss: 0.5637 - val_accuracy: 0.7000
# Epoch 11/30
# 32/32 [==============================] - 1s 46ms/step - loss: 0.5505 - accuracy: 0.7188 - val_loss: 0.4802 - val_accuracy: 0.7500
# Epoch 12/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.5323 - accuracy: 0.7688 - val_loss: 0.4551 - val_accuracy: 0.7500
# Epoch 13/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.4851 - accuracy: 0.8062 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 14/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.5196 - accuracy: 0.7437 - val_loss: 0.3552 - val_accuracy: 1.0000
# Epoch 15/30
# 32/32 [==============================] - 1s 46ms/step - loss: 0.4110 - accuracy: 0.8313 - val_loss: 0.4071 - val_accuracy: 0.8000
# Epoch 16/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.4752 - accuracy: 0.7625 - val_loss: 0.4467 - val_accuracy: 0.8000
# Epoch 17/30
# 32/32 [==============================] - 2s 48ms/step - loss: 0.4063 - accuracy: 0.8500 - val_loss: 0.3493 - val_accuracy: 0.8500
# Epoch 18/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.3851 - accuracy: 0.8313 - val_loss: 0.3055 - val_accuracy: 1.0000
# Epoch 19/30
# 32/32 [==============================] - 1s 46ms/step - loss: 0.4388 - accuracy: 0.8125 - val_loss: 0.3714 - val_accuracy: 0.8000
# Epoch 20/30
# 32/32 [==============================] - 1s 45ms/step - loss: 0.4329 - accuracy: 0.8188 - val_loss: 0.3189 - val_accuracy: 0.9500
# Epoch 21/30
# 32/32 [==============================] - 1s 46ms/step - loss: 0.3771 - accuracy: 0.8188 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 22/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.3736 - accuracy: 0.8188 - val_loss: 0.2844 - val_accuracy: 0.9500
# Epoch 23/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.3009 - accuracy: 0.9000 - val_loss: 0.1771 - val_accuracy: 0.9500
# Epoch 24/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.3938 - accuracy: 0.8313 - val_loss: 0.2948 - val_accuracy: 0.8500
# Epoch 25/30
# 32/32 [==============================] - 2s 48ms/step - loss: 0.3793 - accuracy: 0.8500 - val_loss: 0.2306 - val_accuracy: 0.9500
# Epoch 26/30
# 32/32 [==============================] - 2s 48ms/step - loss: 0.3013 - accuracy: 0.9000 - val_loss: 0.2692 - val_accuracy: 0.8500
# Epoch 27/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.2830 - accuracy: 0.9000 - val_loss: 0.1271 - val_accuracy: 1.0000
# Epoch 28/30
# 32/32 [==============================] - 2s 46ms/step - loss: 0.2717 - accuracy: 0.8875 - val_loss: 0.2520 - val_accuracy: 0.9000
# Epoch 29/30
# 32/32 [==============================] - 2s 46ms/step - loss: 0.2814 - accuracy: 0.8875 - val_loss: 0.3202 - val_accuracy: 0.8500
# Epoch 30/30
# 32/32 [==============================] - 2s 47ms/step - loss: 0.3149 - accuracy: 0.8750 - val_loss: 0.1505 - val_accuracy: 1.0000

# %%
# 결과를 그래프로 표현
acc= history.history['accuracy']
val_acc= history.history['val_accuracy']
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))  
plt.plot(x_len, acc, marker='.', c="red", label='Trainset_acc')
plt.plot(x_len, val_acc, marker='.', c="lightcoral", label='Testset_acc')
plt.plot(x_len, y_vloss, marker='.', c="cornflowerblue", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

plt.legend(loc='upper right') 
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss/acc')
plt.show()
