# %%
import pandas as pd
df = pd.read_csv('./dataset/sonar.csv', header=None)
#df.info()
df.tail()
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          9   ...      51      52      53      54      55      56      57  \
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 205  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 206  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#          58      59  60
# 203  0.0193  0.0157   M
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import numpy as np
import tensorflow as tf
np.random.seed(0)
tf.random.set_seed(0)

# %%
df = pd.read_csv('./dataset/sonar.csv', header=None)
#df.info()
#df.head()
df.iloc[:, -1].unique()
# Out:
# array(['R', 'M'], dtype=object)

# %%
#데이터를 df로 부터 가져옴
dataset = df.values
X = dataset[:, : -1].astype(float)
Y = dataset[:, -1]
#object를 숫자로 변경, 원-핫 인코딩 (분류가 두개 이므로 필요로 하지 않는다)
e = LabelEncoder()
e.fit(Y)
Y_data = e.transform(Y)
#모델을 생성, 실행, 정확도 결과 확인
model = Sequential()
model.add(Dense(30, input_dim=60, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam',
             metrics=['accuracy'])
model.fit(X, Y_data, epochs=200, batch_size=5)

print("\n Accuracy: %.4f" % (model.evaluate(X, Y_data)[1]))
# Out:
# Epoch 1/200
# 42/42 [==============================] - 0s 659us/step - loss: 0.2479 - accuracy: 0.5144
# Epoch 2/200
# 42/42 [==============================] - 0s 635us/step - loss: 0.2345 - accuracy: 0.6635
# Epoch 3/200
# 42/42 [==============================] - 0s 659us/step - loss: 0.2262 - accuracy: 0.6538
# Epoch 4/200
# 42/42 [==============================] - 0s 635us/step - loss: 0.2181 - accuracy: 0.6875
# Epoch 5/200
# 42/42 [==============================] - 0s 635us/step - loss: 0.2112 - accuracy: 0.6779
# Epoch 6/200
# 42/42 [==============================] - 0s 659us/step - loss: 0.1993 - accuracy: 0.7163
# Epoch 7/200
# 42/42 [==============================] - 0s 659us/step - loss: 0.1857 - accuracy: 0.7260
# Epoch 8/200
# 42/42 [==============================] - 0s 635us/step - loss: 0.1803 - accuracy: 0.7163
# Epoch 9/200
# 42/42 [==============================] - 0s 635us/step - loss: 0.1686 - accuracy: 0.7356
# Epoch 10/200
# ...

# %%
####################sona_test_train

# %%
test_data = np.array(test_data)reshape(1,60)
test

# %%
#sonar.csv파일 가져오기
df = pd.read_csv('./dataset/sonar.csv', header=None)
#print(df.info())
#print(df.head())

dataset = df.values
X = dataset[:, :-1].astype(float)
Y_obj = dataset[:, -1]
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,
                                                    random_state=0)
model = Sequential()
model.add(Dense(30, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, ativation='sigmoid'))
model.compile(loss='mean_squared_error',
             optimizer='adam',
             metrics=['accuracy'])

model.fit(X_train, Y_train, epochs=120, batch_swize=5)
#train결과 출력
print("\n Train Accuracy: %.4f" % (model.evaluate(X_train, Y_train)[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15512/3677491912.py in <module>
# ----> 1 X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,
#       2                                                     random_state=0)
#       3 model = Sequential()
#       4 model.add(Dense(30, input_dim=60, activation='relu'))
#       5 model.add(Dense(10, activation='relu'))
#
# NameError: name 'train_test_split' is not defined

# %%
print("\n Train Accuracy: %.4f" % (model.evaluate(X_test, Y_test)[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15512/1831891269.py in <module>
# ----> 1 print("\n Train Accuracy: %.4f" % (model.evaluate(X_test, Y_test)[1]))
#
# NameError: name 'X_test' is not defined
